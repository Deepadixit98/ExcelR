# %% [markdown]
# # Why to visualize data?
# - Data visualization is the practice of translating information into a visual context, such as a map or graph, to make data easier for the human brain to understand and pull insights from. The main goal of data visualization is to make it easier to identify patterns, trends and outliers in large data sets.
#     - Better analysis
#     - Quick action
#     - Identifying patterns
#     - Finding errors
#     - Understanding the story
#     - Exploring business insights
#     - Grasping the Latest Trends
#
# # What is Matplotlib?
#
# - Matplotlib is a python visualisation library, majorly used for plotting 2D data.
# - Matplotlib is a multi-platform data visualization library built on NumPy arrays and designed to work with the broader SciPy stack.
# - Matplotlib consists of several plots like line, bar, scatter, histogram etc.

# %%
import matplotlib as mlb
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # Matplotlib Line plot

# %%
x = np.linspace(1,20,25)
y = np.random.random_sample(25)   #random.random_sample(25) creates the sample of random 25 values

# %%
x
# Out:
# array([ 1.        ,  1.79166667,  2.58333333,  3.375     ,  4.16666667,
#         4.95833333,  5.75      ,  6.54166667,  7.33333333,  8.125     ,
#         8.91666667,  9.70833333, 10.5       , 11.29166667, 12.08333333,
#        12.875     , 13.66666667, 14.45833333, 15.25      , 16.04166667,
#        16.83333333, 17.625     , 18.41666667, 19.20833333, 20.        ])

# %%
y
# Out:
# array([0.58356264, 0.84660761, 0.34586518, 0.70921786, 0.97231545,
#        0.51916829, 0.71835949, 0.36970471, 0.72835946, 0.16178907,
#        0.76357469, 0.85574918, 0.14208812, 0.34389488, 0.82829279,
#        0.38624041, 0.67459821, 0.65206463, 0.68981493, 0.43663362,
#        0.45456844, 0.01228883, 0.83141317, 0.67244544, 0.06436203])

# %%
#  plot teh line graph of x and y 
plt.plot(x,y)

# %%
# set graoh parameters
plt.rcParams['figure.figsize'] = (10,5)    # 10*5 graph size 
plt.rcParams['figure.dpi'] = 500          # pixel size
plt.plot(x,y)

# %%
# color change 
plt.plot(x,y, color ='purple')

# %%
# linestyle  change 
plt.plot(x,y, color ='purple', linestyle = "--")

# %% [markdown]
# ## Multiline graph

# %%
# multiline graph
x= np.arange(1,21)
log = np.log(x)
sqrt = np.sqrt(x)

# %%
plt.plot(x,log)

# %%
plt.plot(x,log)
plt.plot(x,sqrt)

# %%
# lable the value to know which line of which value/ variable ?
plt.plot(x,log, label = 'Log')
plt.plot(x,sqrt, label = 'sqrt')
plt.legend()

# %%
plt.plot(x,log, label = 'Log')
plt.plot(x,sqrt, label = 'sqrt')
plt.xlabel('X- Axis')
plt.ylabel('Y- Axis')
plt.title('Line-Graph')
plt.legend()

# %% [markdown]
# # Matplolib Histogram
# - A histogram is a graph showing **frequency distributions.**
#
# - It is a graph showing the number of **observations within each given interval**.

# %%
df =pd.read_csv('https://raw.githubusercontent.com/aishwaryamate/Datasets/main/cars.csv')

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type   body-style  \
# 0          3                 ?  alfa-romero       gas  convertible
# 1          3                 ?  alfa-romero       gas  convertible
# 2          1                 ?  alfa-romero       gas    hatchback
# 3          2               164         audi       gas        sedan
# 4          2               164         audi       gas        sedan
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# 2          rwd           front   65.5    52.4        ohcv          152
# 3          fwd           front   66.2    54.3         ohc          109
# 4          4wd           front   66.4    54.3         ohc          136
#
#   horsepower  city-mpg  highway-mpg  price
# 0        111        21           27  13495
# 1        111        21           27  16500
# ...

# %%
plt.hist(df['width'])

# if you observe the arrays printed -
#   - the values in the first array are points on Y-axis &
#   - the values in the secomd array are points on X-axis
# Out:
# (array([ 1.,  2., 36., 39., 44., 42., 20.,  7.,  6.,  8.]),
#  array([60.3, 61.5, 62.7, 63.9, 65.1, 66.3, 67.5, 68.7, 69.9, 71.1, 72.3]),
#  <BarContainer object of 10 artists>)

# %%
# skew()function to calculate skewness of the width histogram
df['width'].skew()
# Out:
# 0.904003498786254

# %%
# histograms for all the columns of the dataframe 
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'symboling'}>,
#         <AxesSubplot:title={'center':'width'}>,
#         <AxesSubplot:title={'center':'height'}>],
#        [<AxesSubplot:title={'center':'engine-size'}>,
#         <AxesSubplot:title={'center':'city-mpg'}>,
#         <AxesSubplot:title={'center':'highway-mpg'}>],
#        [<AxesSubplot:title={'center':'price'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# #### The tight_layout function is used to avoid names overlapping.

# %%
#solution for names overlapping  = tight_layout()
df.hist()
plt.tight_layout()

# %%
plt.hist(df['width'])
# Out:
# (array([ 1.,  2., 36., 39., 44., 42., 20.,  7.,  6.,  8.]),
#  array([60.3, 61.5, 62.7, 63.9, 65.1, 66.3, 67.5, 68.7, 69.9, 71.1, 72.3]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Skewness Interpretetions -
# - **mean>median implies that the right tail is longer than left tail  i. e. rightly skewed  i.e  positive skewness**
#
# - **mean < median implies that the left tail is longer than right tail  i. e. leftly skewed  i.e  negative skewness**

# %%
# mean and median
mean = df['width'].mean()
median = df['width'].median()

# %%
# edgecolor
plt.hist(df['width'], edgecolor = 'black')
plt.title('Frequency grapth for width column')
# Out:
# Text(0.5, 1.0, 'Frequency grapth for width column')

# %%
# axvline = axis vertical line 
plt.hist(df['width'], edgecolor = 'black')
plt.axvline(mean, color = 'red')
plt.axvline(median, color = 'green')
plt.title('Frequency grapth for width column')
# Out:
# Text(0.5, 1.0, 'Frequency grapth for width column')

# %% [markdown]
# **we can see that the " mean>median " hence the right tail is longer than left tail  i. e. rightly skewed  i.e  positive skewness**
